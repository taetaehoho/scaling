# %%
import pandas as pd

# %%
df = pd.read_csv("arb_batch_num.csv")
df['block_time'] = pd.to_datetime(df['block_time'])
df = df.set_index('block_time')
daily_counts = df.resample('D').size()

# 1. Convert daily_counts to a DataFrame
daily_counts_df = daily_counts.to_frame(name='count')

# 2. Calculate 30-day moving average and 30-day median
daily_counts_df['30d_moving_avg'] = daily_counts_df['count'].rolling(window=30).mean()
daily_counts_df['30d_moving_median'] = daily_counts_df['count'].rolling(window=30).median()

# 3. Calculate overall median, 25th percentile, 75th percentile, and average
overall_median = daily_counts_df['count'].median()
q25 = daily_counts_df['count'].quantile(0.25)
q75 = daily_counts_df['count'].quantile(0.75)
overall_average = daily_counts_df['count'].mean()

# Display the results
print(daily_counts_df.head())  # to see the first few rows with 30-day calculations
print(f"Overall Median: {overall_median}")
print(f"25th Percentile: {q25}")
print(f"75th Percentile: {q75}")
print(f"Overall Average: {overall_average}")
# Out:
#                            count  30d_moving_avg  30d_moving_median
# block_time
# 2023-01-04 00:00:00+00:00     61             NaN                NaN
# 2023-01-05 00:00:00+00:00    350             NaN                NaN
# 2023-01-06 00:00:00+00:00    362             NaN                NaN
# 2023-01-07 00:00:00+00:00    324             NaN                NaN
# 2023-01-08 00:00:00+00:00    314             NaN                NaN
# Overall Median: 1119.0
# 25th Percentile: 859.0
# 75th Percentile: 1357.0
# Overall Average: 1121.0129449838187

# %%
daily_counts_df[280:]
# Out:
#                            count  30d_moving_avg  30d_moving_median
# block_time
# 2023-10-11 00:00:00+00:00    941     1001.500000              944.0
# 2023-10-12 00:00:00+00:00    847      999.800000              944.0
# 2023-10-13 00:00:00+00:00    737      996.200000              944.0
# 2023-10-14 00:00:00+00:00    616      988.666667              944.0
# 2023-10-15 00:00:00+00:00    615      982.533333              944.0
# 2023-10-16 00:00:00+00:00    929      989.166667              944.0
# 2023-10-17 00:00:00+00:00    867      994.533333              944.0
# 2023-10-18 00:00:00+00:00    865      994.800000              944.0
# 2023-10-19 00:00:00+00:00    852      992.666667              944.0
# 2023-10-20 00:00:00+00:00    916      989.633333              939.5
# 2023-10-21 00:00:00+00:00    836      975.900000              933.5
# 2023-10-22 00:00:00+00:00    843      972.733333              925.5
# 2023-10-23 00:00:00+00:00   1119      984.233333              935.0
# 2023-10-24 00:00:00+00:00   1326     1000.633333              944.0
# 2023-10-25 00:00:00+00:00   1123     1008.700000              952.0
# 2023-10-26 00:00:00+00:00   1195     1016.633333             1000.5
# 2023-10-27 00:00:00+00:00   1119     1012.866667             1000.5
# 2023-10-28 00:00:00+00:00    923      999.333333              944.0
# 2023-10-29 00:00:00+00:00    832      983.700000              935.0
# 2023-10-30 00:00:00+00:00    929      970.600000              929.0
# 2023-10-31 00:00:00+00:00   1082      962.566667              929.0
# 2023-11-01 00:00:00+00:00   1289      969.500000              929.0
# 2023-11-02 00:00:00+00:00   1228      971.633333              929.0
# 2023-11-03 00:00:00+00:00   1226      975.566667              929.0
# 2023-11-04 00:00:00+00:00   1263      981.100000              929.0
# 2023-11-05 00:00:00+00:00   1146      980.333333              929.0
# 2023-11-06 00:00:00+00:00   1086      984.966667              929.0
# 2023-11-07 00:00:00+00:00   1259      999.500000              935.0
# 2023-11-08 00:00:00+00:00   1076     1004.633333              997.5
