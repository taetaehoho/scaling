# %%
import pandas as pd

# %%
df = pd.read_csv("zksync_calldata.csv")
df['block_time'] = pd.to_datetime(df['block_time'])
df = df.set_index('block_time')
daily_counts = df.resample('D').size()

# 1. Convert daily_counts to a DataFrame
daily_counts_df = daily_counts.to_frame(name='count')

# 2. Calculate 30-day moving average and 30-day median
daily_counts_df['30d_moving_avg'] = daily_counts_df['count'].rolling(window=30).mean()
daily_counts_df['30d_moving_median'] = daily_counts_df['count'].rolling(window=30).median()

# 3. Calculate overall median, 25th percentile, 75th percentile, and average
overall_median = daily_counts_df['count'].median()
q25 = daily_counts_df['count'].quantile(0.25)
q75 = daily_counts_df['count'].quantile(0.75)
overall_average = daily_counts_df['count'].mean()

# Display the results
print(daily_counts_df.head())  # to see the first few rows with 30-day calculations
print(f"Overall Median: {overall_median}")
print(f"25th Percentile: {q25}")
print(f"75th Percentile: {q75}")
print(f"Overall Average: {overall_average}")
# Out:
#                            count  30d_moving_avg  30d_moving_median
# block_time
# 2023-03-24 00:00:00+00:00    148             NaN                NaN
# 2023-03-25 00:00:00+00:00    781             NaN                NaN
# 2023-03-26 00:00:00+00:00    862             NaN                NaN
# 2023-03-27 00:00:00+00:00    677             NaN                NaN
# 2023-03-28 00:00:00+00:00    660             NaN                NaN
# Overall Median: 1421.5
# 25th Percentile: 915.25
# 75th Percentile: 1745.5
# Overall Average: 1315.0521739130436

# %%
df
# Out:
#                            batch_num  calldata_bytes_per_tx  txs_per_batch  \
# block_time
# 2023-03-24 10:37:35+00:00        374                    957             35
# 2023-03-24 13:31:23+00:00        397                    336            250
# 2023-03-24 14:10:11+00:00        408                    344            250
# 2023-03-24 14:13:11+00:00        409                    429            250
# 2023-03-24 15:15:47+00:00        434                    358            250
# ...                              ...                    ...            ...
# 2023-11-08 09:34:47+00:00     302934                    223            516
# 2023-11-08 09:35:35+00:00     302935                    201            572
# 2023-11-08 09:36:11+00:00     302936                    199            577
# 2023-11-08 09:36:59+00:00     302937                    204            561
# 2023-11-08 09:37:59+00:00     302938                    210            548
#
#                            data_length
# block_time
# 2023-03-24 10:37:35+00:00        33508
# 2023-03-24 13:31:23+00:00        84164
# 2023-03-24 14:10:11+00:00        86084
# 2023-03-24 14:13:11+00:00       107460
# 2023-03-24 15:15:47+00:00        89668
# ...                                ...
